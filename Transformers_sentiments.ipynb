# %%
from transformers import pipeline
print("Hello hugging face")
# Out:
# Hello hugging face

# %%
from transformers import AutoModel, AutoTokenizer
model_name= "google-bert/bert-base-uncased"
tokenizer= AutoTokenizer.from_pretrained(model_name)
model= AutoModel.from_pretrained(model_name)
print("let's go.")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# let's go.

# %%
text= "Exploring transformers with hugging face is fascinating!"
tokens= tokenizer.tokenize(text)
print(tokens)
# Out:
# ['exploring', 'transformers', 'with', 'hugging', 'face', 'is', 'fascinating', '!']

# %%
from transformers import pipeline
sentiment_analyzer= pipeline("sentiment-analysis")
sentiment= sentiment_analyzer("Les burundais sont très intelligents!")
print(sentiment)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9945175051689148}]
